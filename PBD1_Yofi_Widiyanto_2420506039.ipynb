# %% [markdown]
# # 1. Instal pyspark dan pandas pada python di google colab

# %%
# !pip install pyspark
# !pip install pandas

# %% [markdown]
# # 2. Pengenalan dan Praktik Dasar PySpark dan Pandas
# - **Langkah 1: Praktik dengan PySpark**
#   Buat program sederhana untuk memulai dengan PySpark. Gunakan PySpark untuk membuat DataFrame dan memanipulasi data sederhana:

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Ali", 34), ("Budi", 23), ("Citra", 29), ("Dina", 45)]
columns = ["Nama", "Usia"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFrame
df.show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+

# %% [markdown]
# - **Tugas 1**: Jalankan kode di atas dan buat modifikasi dengan menambahkan data lain berupa kolom pekerjaan, hobi dan gender:

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Ali", 34, "Dummy", "Dummy", "L"), ("Budi", 23, "Dummy", "Dummy", "L"), ("Citra", 29, "Dummy", "Dummy", "P"), ("Dina", 45, "Dummy", "Dummy", "P")]
columns = ["Nama", "Usia", "Pekerjaan", "Hobi", "Gender"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFrame
df.show()
# Out:
# +-----+----+---------+-----+------+
# | Nama|Usia|Pekerjaan| Hobi|Gender|
# +-----+----+---------+-----+------+
# |  Ali|  34|    Dummy|Dummy|     L|
# | Budi|  23|    Dummy|Dummy|     L|
# |Citra|  29|    Dummy|Dummy|     P|
# | Dina|  45|    Dummy|Dummy|     P|
# +-----+----+---------+-----+------+

# %% [markdown]
# # 3. Praktik PySpark Lanjutan
# - **Latihan 1**: Memanipulasi Data dengan PySpark.

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Ali", 34), ("Budi", 23), ("Citra", 29), ("Dina", 45)]
columns = ["Nama", "Usia"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFrame
df.show()

# Filtering data
df_filtered = df.filter(df['Usia'] > 30)
df_filtered.show()

# Menghitung rata-rata usia
from pyspark.sql.functions import avg
df.groupBy().agg(avg("Usia")).show()

# Mengurutkan data berdasarkan usia
df_sorted = df.orderBy("Usia", ascending=False)
df_sorted.show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+
#
# +----+----+
# |Nama|Usia|
# +----+----+
# | Ali|  34|
# |Dina|  45|
# +----+----+
#
# +---------+
# |avg(Usia)|
# +---------+
# |    32.75|
# +---------+
#
# +-----+----+
# | Nama|Usia|
# +-----+----+
# | Dina|  45|
# |  Ali|  34|
# |Citra|  29|
# | Budi|  23|
# +-----+----+

# %% [markdown]
# - **Tugas 2**: Lakukan filter, penghitungan rata-rata, dan pengurutan data menggunakan PySpark:

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Ali", 34), ("Budi", 23), ("Citra", 29), ("Dina", 45)]
columns = ["Nama", "Usia"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFrame
df.show()

# Filtering data
df_filtered = df.filter(df['Usia'] > 30)
df_filtered.show()

# Menghitung rata-rata usia
from pyspark.sql.functions import avg
df.groupBy().agg(avg("Usia")).show()

# Mengurutkan data berdasarkan usia
df_sorted = df.orderBy("Usia", ascending=False)
df_sorted.show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+
#
# +----+----+
# |Nama|Usia|
# +----+----+
# | Ali|  34|
# |Dina|  45|
# +----+----+
#
# +---------+
# |avg(Usia)|
# +---------+
# |    32.75|
# +---------+
#
# +-----+----+
# | Nama|Usia|
# +-----+----+
# | Dina|  45|
# |  Ali|  34|
# |Citra|  29|
# | Budi|  23|
# +-----+----+

# %% [markdown]
# # 4. Praktik dengan Pandas
# - **Latihan 2**:  Buat DataFrame menggunakan Pandas:

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Imam", "Revan", "Oliv", "Beta"], "Usia": [34, 23, 27, 20]}
df_pandas = pd.DataFrame(data_pandas)

# Menampilkan DataFrame Pandas
df_pandas
# Out:
#     Nama  Usia
# 0   Imam    34
# 1  Revan    23
# 2   Oliv    27
# 3   Beta    20

# %% [markdown]
# - **Tugas 3**: Modifikasi DataFrame Pandas dengan menambahkan kolom baru dan melakukan operasi seperti filtering data berdasarkan usia:

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Imam", "Revan", "Oliv", "Beta"], "Usia": [34, 23, 27, 20], "Pekerjaan": ["Dummy", "Dummy", "Dummy", "Dummy"], "Hobi": ["Dummy", "Dummy", "Dummy", "Dummy"], "Gender": ["L", "L", "P", "P"]}
df_pandas = pd.DataFrame(data_pandas)

# Membuat filter berdasarkan usia dibawah 30
df_filtered = df_pandas.query("Usia < 30")

# Menampilkan DataFrame Pandas
display(df_pandas)
print()
display(df_filtered)
# Out:
#     Nama  Usia Pekerjaan   Hobi Gender
# 0   Imam    34     Dummy  Dummy      L
# 1  Revan    23     Dummy  Dummy      L
# 2   Oliv    27     Dummy  Dummy      P
# 3   Beta    20     Dummy  Dummy      P
#     Nama  Usia Pekerjaan   Hobi Gender
# 1  Revan    23     Dummy  Dummy      L
# 2   Oliv    27     Dummy  Dummy      P
# 3   Beta    20     Dummy  Dummy      P

# %% [markdown]
# # 5. Praktik Pandas Lanjutan
# - **Latihan 3**: Penggunaan Pandas untuk operasi lebih kompleks.

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Imam", "Revan", "Oliv", "Beta"], "Usia": [34, 23, 27, 20]}
df_pandas = pd.DataFrame(data_pandas)

# Membuat DataFrame kedua
data_pandas_2 = {"Nama": ["Imam", "Revan", "Oliv", "Beta"], "Pekerjaan": ["Dokter", "Guru", "Insinyur", "Perawat"]}
df_pandas_2 = pd.DataFrame(data_pandas_2)

# Join antara dua DataFrame
df_joined = pd.merge(df_pandas, df_pandas_2, on="Nama")
print(df_joined)

# Menghitung statistik deskriptif
print(df_pandas.describe())

# Plotting Data
import matplotlib.pyplot as plt
df_pandas['Usia'].plot(kind='bar')
plt.show()
# Out:
#     Nama  Usia Pekerjaan
# 0   Imam    34    Dokter
# 1  Revan    23      Guru
# 2   Oliv    27  Insinyur
# 3   Beta    20   Perawat
#             Usia
# count   4.000000
# mean   26.000000
# std     6.055301
# min    20.000000
# 25%    22.250000
# 50%    25.000000
# 75%    28.750000
# max    34.000000

# %% [markdown]
# - **Tugas 4**: Lakukan penggabungan DataFrame dan visualisasikan data dengan Pandas.

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Imam", "Revan", "Oliv", "Beta"], "Usia": [34, 23, 27, 20]}
df_pandas = pd.DataFrame(data_pandas)

# Membuat DataFrame kedua
data_pandas_2 = {"Nama": ["Imam", "Revan", "Oliv", "Beta"], "Pekerjaan": ["Dokter", "Guru", "Insinyur", "Perawat"]}
df_pandas_2 = pd.DataFrame(data_pandas_2)

# Join antara dua DataFrame
df_joined = pd.merge(df_pandas, df_pandas_2, on="Nama")
display(df_joined)
print()

# Menghitung statistik deskriptif
display(df_pandas.describe())
print()

# Plotting Data
import matplotlib.pyplot as plt
df_pandas['Usia'].plot(kind='bar')
plt.show()
# Out:
#     Nama  Usia Pekerjaan
# 0   Imam    34    Dokter
# 1  Revan    23      Guru
# 2   Oliv    27  Insinyur
# 3   Beta    20   Perawat
#             Usia
# count   4.000000
# mean   26.000000
# std     6.055301
# min    20.000000
# 25%    22.250000
# 50%    25.000000
# 75%    28.750000
# max    34.000000

# %% [markdown]
# # 5. Menggabungkan PySpark dan Pandas
# - **Latihan 4: Mengonversi DataFrame antara PySpark dan Pandas**
#   Praktik untuk convert DataFrame dari PySpark ke Pandas dan sebaliknya:

# %%
# Mengonversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengonversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konversi
df_pandas_from_spark, df_spark_from_pandas.show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# | Imam|  34|
# |Revan|  23|
# | Oliv|  27|
# | Beta|  20|
# +-----+----+
# (    Nama  Usia
#  0    Ali    34
#  1   Budi    23
#  2  Citra    29
#  3   Dina    45,
#  None)

# %% [markdown]
# - **Tugas 5**: Gunakan metode ini untuk menggabungkan data yang Anda buat di PySpark dengan data dari Pandas, kemudian lakukan analisis sederhana seperti menghitung rata-rata usia.

# %%
# Mengonversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengonversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konversi
#df_pandas_from_spark, df_spark_from_pandas.show()

# Gabung data spark dan pandas ke pandas
df_joined_pandas = pd.concat([df_pandas_from_spark, df_pandas], ignore_index=True)

# Rata-rata usia gabungan pandas
joined_avg = df_joined_pandas['Usia'].mean()

# Menampilkan
display(df_joined_pandas)
print(f"\nRata-rata usia di DataFrame gabungan: {joined_avg}")
# Out:
#     Nama  Usia
# 0    Ali    34
# 1   Budi    23
# 2  Citra    29
# 3   Dina    45
# 4   Imam    34
# 5  Revan    23
# 6   Oliv    27
# 7   Beta    20
# Rata-rata usia di DataFrame gabungan: 29.375

# %% [markdown]
# # 6. Konversi Data antara PySpark dan Pandas

# %%
# Mengonversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengonversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konversi
df_pandas_from_spark, df_spark_from_pandas.show()

# %% [markdown]
# - **Tugas 6**: Gabungkan data dari PySpark dan Pandas, lalu lakukan operasi statistik seperti menghitung nilai maksimum usia.

# %%
# Mengonversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengonversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konversi
#df_pandas_from_spark, df_spark_from_pandas.show()

# Gabung data spark dan pandas ke pandas
df_joined_pandas = pd.concat([df_pandas_from_spark, df_pandas], ignore_index=True)
display(df_joined_pandas)

# Menghitung nilai max
joined_max = df_joined_pandas["Usia"].max()
print(f"\nNilai max usia: {joined_max}")
# Out:
#     Nama  Usia
# 0    Ali    34
# 1   Budi    23
# 2  Citra    29
# 3   Dina    45
# 4   Imam    34
# 5  Revan    23
# 6   Oliv    27
# 7   Beta    20
# Nilai max usia: 45
